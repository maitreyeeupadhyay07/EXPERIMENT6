# %%
#EXPERIMENT 6 STUDY OF CONDITIONAL STATEMENTS IN PYTHON
#MAITREYEE UPADHYAY 25070123071


#6A : CHECK WHETHER A NUMBER IS POSITIVE, NEGATIVE OR ZERO
num = int(input("Enter a number: "))

if num > 0:
             print("positive")
elif num == 0:
             print("zero")
else:
             print("negative")
# Out:
# Enter a number: 67
# positive

# %%
#6B : CHECK WHETHER A NUMBER IS EVEN OR ODD

num = int(input("Enter a number: "))
if num % 2 == 0:
  print(num, "is even")
else:
  print(num, "is odd")
# Out:
# Enter a number: 7
# 7 is odd

# %%
#6C FIND THE LARGEST OF THREE NUMBERS
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

if a>=b and a>=c:
  print(a, "is largest:")
elif b>=a and b>=c:
  print(b, "is largest:")
else:
  print(c, "is largest")
# Out:
# Enter first number: 4
# Enter second number: 6
# Enter third number: 9
# 9 is largest

# %%
#6D GET INPUT FROM USER FOR ONE SUBJECT AND CALC GRADE USING IF-ELIF-ELSE
marks = float(input("Enter marks : "))

if a >=90:
  print("grade a")
elif a >= 80:
  print("grade b")
elif a >= 70:
  print("grade c")
elif a >= 60:
  print("grade d")
else:
  print("grade f")
# Out:
# Enter marks : 58
# grade f

# %%
#6E CHECK WHETHER A YEAR IS A LEAP YEAR
year = int(input("Enter a year: "))
if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
  print(year, "is a leap year")
else:
  print(year, "is not a leap year")
# Out:
# Enter a year: 1900
# 1900 is not a leap year
